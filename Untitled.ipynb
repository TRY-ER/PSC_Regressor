# %%
import joblib

# %%
f = joblib.load("propdict.z")

# %%
# Out:
# {'Cell_area_measured_numeric': {'min': 0.0004,
#   'max': 100.0,
#   'count': 46820,
#   'u_val': array([0.2       , 0.1       , 0.06      , ..., 0.08485552, 0.10771803,
#          0.15230928]),
#   'unique_count': 15152,
#   'type': 'numeric'},
#  'Cell_architecture_cat': {'min': 'Back contacted',
#   'max': 'pin',
#   'count': 46820,
#   'u_val': array(['nip', 'pin', 'Back contacted'], dtype=object),
#   'unique_count': 3,
#   'type': 'categorical'},
#  'Substrate_stack_sequence_0': {'min': 'Ag-nw',
#   'max': 'Willow glass ',
#   'count': 46820,
#   'u_val': array(['SLG ', 'PET ', 'PEN ', 'Paper ', 'Transparent wood ', 'PET',
#          'NOA63 ', 'SLG', 'Ti-foil', 'Polyester-satin textile', 'PEG ',
#          'Regenerated cellulose film ', 'Mica ', 'Polyimide ',
#          'Cellophane ', 'PI ', 'Ag-nw', 'Cu-nw', 'PETUG', 'Quartz ',
#          'HCLaminate ', 'Nanopaper ', 'Ti', 'Silk ', 'SLG-HAMC-patterned ',
#          'PES ', 'NOA88 ', 'Willow glass '], dtype=object),
# ...
