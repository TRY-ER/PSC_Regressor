# %%
import joblib
import random
import pandas as pd
import os
import optuna 
import torch 
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader
from torchmetrics import R2Score
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
FOLD_DICT = joblib.load("../input/perov-fold-data/fold_data_export.z")
USE_DF = pd.read_csv("../input/perov-scaled-data/scaled_trainable.csv")
TAR_COL = "JV_default_PCE_numeric"
EPOCHS = 700
K_FOLD = 20
IN_FEATURES = 103

# %%
#preparing the dataset class for the input
class CustDataset(Dataset):
    
    def __init__(self,df):
        self.labels = df[TAR_COL].to_numpy(dtype=np.float64)
        self.features = df.drop([TAR_COL],axis=1).to_numpy(dtype=np.float64)
        
    def classes(self):
        return self.labels
    def __len__(self):
        return len(self.labels)
    def get_batch_labels(self,idx):
        return np.array(self.labels[idx])
    
    def get_batch_features(self,idx):
        return np.array(self.features[idx])
    
    def __getitem__(self,idx):
        batch_features = self.get_batch_features(idx)
        batch_y = self.get_batch_labels(idx)
        
        return batch_features, batch_y

# %%
#Building the MLP
class MLP(torch.nn.Module):
    def __init__(self,in_feature):
        super(MLP,self).__init__()
        self.in_feature = in_feature
        self.hid1 = torch.nn.Linear(in_feature, 128)
        self.dropout = nn.Dropout(0.25)
        self.batchnorm1 = nn.BatchNorm1d(128)
        self.hid2 = torch.nn.Linear(128,64)
        self.hid3 = torch.nn.Linear(64,32)
        self.output = torch.nn.Linear(32,1)
        
        torch.nn.init.xavier_uniform_(self.hid1.weight)
        torch.nn.init.zeros_(self.hid1.bias)
        torch.nn.init.xavier_uniform_(self.hid2.weight)
        torch.nn.init.zeros_(self.hid2.bias)
        torch.nn.init.xavier_uniform_(self.hid3.weight)
        torch.nn.init.zeros_(self.hid3.bias)
        torch.nn.init.xavier_uniform_(self.output.weight)
        torch.nn.init.zeros_(self.output.bias)
    
    def forward(self,x):
        z = torch.relu(self.hid1(x))
        z = self.batchnorm1(z)
#         z = self.dropout(z)
        z = torch.relu(self.hid2(z))
#         z = self.dropout(z)
        z = torch.relu(self.hid3(z))
        z = self.output(z)
        print(x.shape)
        print(z.shape)
        return z

# %%
#Redirecting the MLP 

def build_model(in_features):
    return MLP(in_features)

# %%
def train_eval(params, model,fold,trial):
    
    #loading data 
    train_index = FOLD_DICT[fold]["train"]
    test_index = FOLD_DICT[fold]["test"]
    train = CustDataset(USE_DF.iloc[train_index,:])
    val = CustDataset(USE_DF.iloc[test_index,:])
    train_loader = DataLoader(train,batch_size = 32, shuffle=False)
    val_loader = DataLoader(val,batch_size= 32, shuffle=False)
    
    cuda_bool = torch.cuda.is_available()
    device = torch.device("cuda" if cuda_bool else "cpu")
    
    criterion = nn.MSELoss()
    optimizer = getattr(optim, params["optimizer"])(model.parameters(),lr=params["learning_rate"])
    
    #creating custom early stopping
    patience = 5
    best_val_loss = float("inf")
    counter = 0
    
    if cuda_bool:
        model = model.cuda()
        criterion = criterion.cuda()
        
    
    
    for epoch_num in range(EPOCHS):
        
        loss_list = []
        #training loop 
        for train_x, train_y in train_loader:
            
            train_y = train_y.to(device)
            train_y = train_y.reshape((train_y.shape[0],1))
            train_x = train_x.to(device)
            
            output = model(train_x.float())
            
            batch_loss = criterion(output, train_y.float())
            
            optimizer.zero_grad()
            
            model.zero_grad()
            batch_loss.backward()
            optimizer.step()


          
        
        model.eval()
        with torch.no_grad():
            
            loss = 0.0
            #validation loop 
            for val_x,val_y in val_loader:
                
                val_x = val_x.to(device)
                val_y = val_y.reshape((val_y.shape[0],1))
                val_y = val_y.to(device)
                
                output = model(val_x.float())
                
                batch_loss = criterion(output, val_y.float())
                loss += batch_loss.item()
                loss_list.append(batch_loss.item())
            print(f"Validating:[{epoch_num+1}/{EPOCHS}] LOSS: {batch_loss.item()}]")
        if loss < best_val_loss:
            best_val_loss = loss
            counter = 0
        else: 
            counter += 1
            if counter >= patience: 
                print(f"[==] Early Stopping at {loss}")
                break
        
    main_loss = np.mean(loss_list)
    return main_loss

# %%
#defing optuna objective function
def objective(trial):
    params = {
        "learning_rate": trial.suggest_float("learning_rate",1e-5, 1e-1),
        "optimizer" : trial.suggest_categorical("optimizer",["Adam", "RMSprop", "SGD"])
    }
    
    fold = TRIAL_FOLD
    model = build_model(IN_FEATURES)
    main_loss = train_eval(params, model,fold, trial)
    
    return main_loss

# %%
# Definging best hyper parameteres
NUM_TRIALS = 2
TRIAL_FOLD = random.choice([x for x in range(K_FOLD)])
study = optuna.create_study(direction="minimize",
                            sampler=optuna.samplers.TPESampler(),
                            pruner=optuna.pruners.MedianPruner())
study.optimize(objective, n_trials=NUM_TRIALS)
# Out:
# [I 2023-01-10 09:41:54,793] A new study created in memory with name: no-name-c7c7a3b4-d80e-455a-867a-9f93e60ecbe2
# Validating:[1/6] LOSS: 0.2088537961244583]
# Validating:[2/6] LOSS: nan]
# Validating:[3/6] LOSS: nan]
# Validating:[4/6] LOSS: nan]
# Validating:[5/6] LOSS: nan]
# [W 2023-01-10 09:42:18,658] Trial 0 failed, because the objective function returned nan.
# Validating:[6/6] LOSS: nan]
# [==] Early Stopping at nan
# Validating:[1/6] LOSS: 0.1279267817735672]
# Validating:[2/6] LOSS: 1.0603351593017578]
# Validating:[3/6] LOSS: 0.122390016913414]
# Validating:[4/6] LOSS: 0.17076396942138672]
# Validating:[5/6] LOSS: 0.20781931281089783]
# [I 2023-01-10 09:42:46,519] Trial 1 finished with value: 77.36025242507458 and parameters: {'learning_rate': 0.08639371377504378, 'optimizer': 'RMSprop'}. Best is trial 1 with value: 77.36025242507458.
# Validating:[6/6] LOSS: 0.20781931281089783]

# %%
#CAPTURING BEST HYPERPARAMETERS
best_param = study.best_params
best_param
# Out:
# {'learning_rate': 0.08639371377504378, 'optimizer': 'RMSprop'}

# %%
#Creating train function for all folds
def main_train(best_param, model,fold):
    
    #loading data 
    train_index = FOLD_DICT[fold]["train"]
    test_index = FOLD_DICT[fold]["test"]
    train = CustDataset(USE_DF.iloc[train_index,:])
    val = CustDataset(USE_DF.iloc[test_index,:])
    train_loader = DataLoader(train,batch_size = 32, shuffle=False)
    val_loader = DataLoader(val,batch_size= 32, shuffle=False)
    
    cuda_bool = torch.cuda.is_available()
    device = torch.device("cuda" if cuda_bool else "cpu")
    
    criterion = nn.MSELoss()
    optimizer = getattr(optim,best_param["optimizer"])(model.parameters(),lr=best_param["learning_rate"])
    
    
    #creating custom early stopping
    patience = 5
    best_val_loss = float("inf")
    counter = 0 
    
    
    if cuda_bool:
        model = model.cuda()
        criterion = criterion.cuda()
        
    
    
    for epoch_num in range(EPOCHS):
        
        mean_sq_list = []
        r_mean_sq_list = []
        mean_abs_list = []
        r2_list = []
        #training loop 
        for train_x, train_y in train_loader:
            
            train_y = train_y.to(device)
            train_y = train_y.reshape((train_y.shape[0],1))
            train_x = train_x.to(device)
            
            print(train_x.shape)
            output = model(train_x.float())
            print(output.shape)
            batch_loss = criterion(output, train_y.float())
            print(batch_loss)
            optimizer.zero_grad()
            
            model.zero_grad()
            batch_loss.backward()
            optimizer.step()


          
        
        model.eval()
        with torch.no_grad():
            
            #validation loop 
            loss = 0.0
            for val_x,val_y in val_loader:
                
                val_x = val_x.to(device)
                val_y = val_y.reshape((val_y.shape[0],1))
                val_y = val_y.to(device)
                
                output = model(val_x.float())
                
                batch_loss = criterion(output, val_y.float())
                loss += batch_loss.item()
                mean_abs_error = nn.L1Loss()(output, val_y)
                r_mean_sq_error = torch.sqrt(batch_loss)
                r2_score = R2Score().to(device)(output, val_y)
                mean_sq_list.append(batch_loss.item())
                mean_abs_list.append(mean_abs_error.item())
                r2_list.append(r2_score.item())
                r_mean_sq_list.append(r_mean_sq_error.item())
            print(f"Validating:[{epoch_num+1}/{EPOCHS}] LOSS: {batch_loss.item()}]")
        if loss < best_val_loss:
            best_val_loss = loss
            counter = 0
        else: 
            counter += 1
            if counter >= patience: 
                print(f"[==] Early Stopping at {loss}")
                break
        
    sq_mean_loss = np.mean(mean_sq_list)
    r_sq_mean_loss = np.mean(r_mean_sq_list)
    abs_mean_loss = np.mean(mean_abs_list)
    r2_mean_loss = np.mean(r2_list)
    
    error = {"mse_error" : sq_mean_loss ,
    "mae_error" : abs_mean_loss,
    "rmse_error" : r_sq_mean_loss,
    "r2_score" :  r2_mean_loss}
    return error,model

# %%
def save_cv_model(i,model_name,model,optim,losses,output_path="./"):

    ''' This function saves cross validation model in the corresponding directory ( if the path does not exist it creates the path for it'''


    if os.path.exists(os.path.join(output_path,f"{i}_{model_name}_{optim}")):
        torch.save(model, os.path.join(output_path,f"{i}_{model_name}_{optim}/{i}_model.z"))
        with open(os.path.join(output_path,f"{i}_{model_name}_{optim}/losses_{fold}.txt"),"w+") as file:file.write(f" mse_loss :: {str(losses)}")
    else:
        os.mkdir(os.path.join(output_path,f"{i}_{model_name}_{optim}"))
        torch.save(model, os.path.join(output_path,f"{i}_{model_name}_{optim}/{i}_model.z"))
        with open(os.path.join(output_path,f"{i}_{model_name}_{optim}/losses_{fold}.txt"),"w+") as file:file.write(f" mse_loss :: {str(losses)}")

# %%
model_name = "MLP"
optim_name = best_param["optimizer"]
for fold in [x for x in range(K_FOLD)]:
    dum_model = build_model(IN_FEATURES)
    print(f"Training for fold [{fold+1}/{K_FOLD}] started ")
    error,model = main_train(best_param,dum_model,fold)
    print(f"Saving data for fold [{fold+1}/{K_FOLD}]")
    save_cv_model(fold,model_name,model,optim_name,error,output_path="./")
# Out:
# Training for fold [1/20] started
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(172.6291, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(1.6301e+08, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(249.0907, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(22569.2891, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(225.2901, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(145.9198, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(130.1539, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(228.2820, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(292.2666, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(128.4435, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(1212.7709, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(746.9868, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(139.3936, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor
grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(34.2719, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.0367, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(52.5561, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(39.2947, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(25.3134, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.2723, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.8057, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(31.9909, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(23.6789, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(35.4957, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(42.0052, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(37.0559, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(54.3911, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(79.4863, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.5900, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(23.3563, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(46.0124, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(20.1045, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(51.8689, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(136.9013, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(75.0345, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(19.7692, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.9123, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(79.6241, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(71.0208, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(49.4001, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(34.5003, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(34.8031, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.4864, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.5568, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.2626, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(25.6719, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(36.2146, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(67.4384, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(42.9397, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.9001, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(79.3545, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(27.4795, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(49.9849, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(57.7881, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(53.8542, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(33.2435, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(40.8896, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(21.1299, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(49.5302, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(24.3141, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(36.3704, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(32.0178, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(18.2117, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(25.2031, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(66.0584, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(27.4663, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(16.6989, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(31.1190, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.5989, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(48.9889, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(26.7931, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(43.7226, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.5450, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.4544, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.0066, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(46.7013, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.9286, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(17.3492, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.4294, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(40.9977, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(38.0711, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(44.6122, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(25.6033, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(33.1439, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(257.6282, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(51.7993, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(70.6779, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(81.8209, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(68.4673, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(66.8351, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(32.5718, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(79.7902, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(52.8096, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(61.7312, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(23.0907, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(44.9907, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(43.3368, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(24.4164, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(12.7627, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.9357, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(40.8687, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.6356, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(43.8676, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.9357, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(23.2394, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(11.8491, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(77.9344, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.3549, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(18.8508, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(52.1644, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.7376, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(66.3224, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(47.9817, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.7819, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(51.9863, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(30.5735, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(31.7057, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.8400, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(26.4311, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(19.7595, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(51.4798, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(36.3858, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(26.7031, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(36.2482, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(63.2609, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(47.6023, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(20.7935, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(65.4346, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(35.2857, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(22.7545, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(48.4612, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(49.5280, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(21.6374, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.5486, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(11.2588, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(21.6728, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(33.5703, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.0912, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(16.0975, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(64.3550, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.8742, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(28.2856, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(62.6150, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(17.9520, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.9819, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(37.2869, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(41.6667, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(33.1097, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(47.5677, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(19.9463, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(24.8161, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(19.3211, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.3170, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(16.6423, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(35.4444, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(27.5780, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(45.0503, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(31.5288, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(24.9422, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(22.4057, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(53.9143, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# torch.Size([32, 103])
# torch.Size([32, 1])
# torch.Size([32, 1])
# tensor(29.3934, grad_fn=<MseLossBackward>)
# torch.Size([32, 103])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_20/264271165.py in <module>
#       4     dum_model = build_model(IN_FEATURES)
#       5     print(f"Training for fold [{fold+1}/{K_FOLD}] started ")
# ----> 6     error,model = main_train(best_param,dum_model,fold)
#       7     print(f"Saving data for fold [{fold+1}/{K_FOLD}]")
#       8     save_cv_model(fold,model_name,model,optim_name,error,output_path="./")
#
# /tmp/ipykernel_20/3333395001.py in main_train(best_param, model, fold)
#      43
#      44             print(train_x.shape)
# ---> 45             output = model(train_x.float())
#      46             print(output.shape)
#      47             batch_loss = criterion(output, train_y.float())
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /tmp/ipykernel_20/2315447377.py in forward(self, x)
#      26         z = torch.relu(self.hid2(z))
#      27 #         z = self.dropout(z)
# ---> 28         z = torch.relu(self.hid3(z))
#      29         z = self.output(z)
#      30         print(x.shape)
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     766         if '_parameters' in self.__dict__:
#     767             _parameters = self.__dict__['_parameters']
# --> 768             if name in _parameters:
#     769                 return _parameters[name]
#     770         if '_buffers' in self.__dict__:
#
# KeyboardInterrupt:
